# %% [markdown]
# # <font color='red'>Matrices<font>

# %%
import numpy as np

# %% [markdown]
# # Addition

# %%
x = np.array([3,8,4,6])

# %%
x
# Out:
# array([3, 8, 4, 6])

# %%
y = np.array([4,0,1,-9])

# %%
y
# Out:
# array([ 4,  0,  1, -9])

# %%
x + y
# Out:
# array([ 7,  8,  5, -3])

# %% [markdown]
# # Negative

# %%
x = np.array([2,-4,7,10])

# %%
x
# Out:
# array([ 2, -4,  7, 10])

# %% [raw]
# -(2,-4,7,10) => (-2,4,-7,-10)

# %% [markdown]
# # Subtracting

# %%
x = np.array([3,8,4,6])

# %%
y = np.array([4,0,1,-9])

# %%
x - y
# Out:
# array([-1,  8,  3, 15])

# %% [markdown]
# # Multiply by a Constant

# %%
x = np.array([4,0,1,-9])

# %%
x
# Out:
# array([ 4,  0,  1, -9])

# %%
2 *x
# Out:
# array([  8,   0,   2, -18])

# %%
# We call the constant a scalar, so officially this is called "scalar multiplication".

# %%
# Multiplying a Matrix by Another Matrix

# %% [raw]
# But to multiply a matrix by another matrix we need to do the "dot product" of rows and columns

# %% [markdown]
# # <font color='green'>Vector<font>

# %% [markdown]
# ![Screenshot%202023-09-21%20at%2012.05.04%20PM.png](attachment:Screenshot%202023-09-21%20at%2012.05.04%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-21%20at%2012.05.18%20PM.png](attachment:Screenshot%202023-09-21%20at%2012.05.18%20PM.png)

# %% [raw]
# There things here for vectors:
#     1) Speed(Velocity)
#     2) Acceleration
#     3) Force

# %% [markdown]
# # <font color='blue'>Speed (Velocity)<font>

# %% [raw]
# These are the most common measurements:
#
# Metres per second (m/s)
# Kilometres per hour (km/h)

# %% [raw]
# Speed in metres per second (m/s)
# If something is travelling at 1 m/s it moves 1 metre every second.
#
# It is a gentle walking speed.
#
# One hour walking at 1 m/s moves you 3.6 km.

# %% [raw]
# Speed in kilometres per hour (km/h)
# If something is travelling at 1 km/h it moves 1 kilometre every hour.
#
# 1 km/h is like a very slow walking speed.
#
# Kilometres per hour is often used for car speeds.

# %% [raw]
# Converting
# You can convert from m/s to km/h:
#
# 1 m/s = 3.6 km/h
# 1 km/h = 0.2777... m/s
# Example: What is 100 km/h in m/s?
# A kilometre has 1,000 metres, and an hour has 3,600 seconds, so 100 kilometres per hour is:
#
# 100 x 1,000 / 3,600 = 27.777... m/s
# 100 km/h = 27.78 m/s (to 2 decimal places)

# %%
# Velocity

# %% [raw]
# Velocity is speed with a direction.
#
# So if something is moving at 5 km/h that is a speed.
#
# But when we say it is moving at 5 km/h westwards that is a velocity.
#
# If something moves backwards and forwards very fast it has a high speed, but a low (or zero) velocity

# %% [raw]
# Examples
# 100 km/h is about:
#
# -> how fast we can legally go on many highways
# -> the maximum running speed of a cheetah
#
# 60 km/h is about:
#
# -> going very fast on a bicycle
# -> the speed needed to go one kilometre in a minute

# %% [raw]
# 1 metre per second is: about 3.2808 feet per second
#
# 1 kilometre per hour is about 0.9113 feet per second

# %% [markdown]
#  # <font color='blue'>Acceleration<font>

# %% [raw]
# Acceleration is how fast velocity changes:
#
# -> Speeding up
# -> Slowing down (also called deceleration)
# -> Changing direction

# %% [raw]
# It is usually shown as:
#
# m/s2 "metres per second squared"

# %%
# What is this "per second squared" thing? An example will help:

# %% [raw]
# A runner accelerates from 5 m/s (5 metres per second) to 6 m/s in just one second
# So they accelerate by 1 metre per second per second
#
# See how "per second" is used twice?
#
# It can be thought of as (m/s)/s but is usually written m/s2
#
# So their acceleration is 1 m/s2

# %% [raw]
# Acceleration =  Change in Velocity (m/s) / Time (s)

# %% [markdown]
# ![Screenshot%202023-09-21%20at%2012.33.15%20PM.png](attachment:Screenshot%202023-09-21%20at%2012.33.15%20PM.png)

# %% [markdown]
# ![Screenshot%202023-09-21%20at%2012.35.16%20PM.png](attachment:Screenshot%202023-09-21%20at%2012.35.16%20PM.png)

# %% [raw]
# a + b = ab (16 + 16 = 32)   this is called vector

# %% [markdown]
#  # <font color='blue'>Force<font>

# %% [raw]
# Force is push or pull.
#
# Unbalanced forces make an object accelerate

# %%
# Balanced

# %% [raw]
# Forces on an object are usually balanced: forces in one direction are equal to forces in the opposite direction:
#
# forces balanced

# %% [raw]
# Examples of Balanced Forces
# No acceleration.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Example: The forces are in balance at the top of this bridge tower.

# %%
# Unbalanced

# %% [raw]
# But when forces are unbalanced the object accelerates.

# %% [raw]
# Examples of Unbalanced Forces.
# There is acceleration.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Kicking a ball is an unbalanced force that makes it accelerate very quickly.
#
# Once it loses contact with your foot that force (and its acceleration) stops.

# %% [raw]
# Gravity is now an unbalanced force that makes the ball accelerate downwards.
# Air resistance is also an unbalanced force which gradually reduces the velocity of the ball.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Force and Acceleration are linked.
#
# The more force, the more acceleration.
#
# But objects with more mass are harder to accelerate
#
# The more mass, the less acceleration.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# F = ma
#
# "Newton's Second Law of Motion"
# (F is force, m is mass and a is acceleration)

# %% [raw]
# Dividing both sides by m makes it clearer:
#
# f/m = a
#
#
# The idea that mass resists acceleration is called inertia.
#
# Inertia means the object wants to continue to do what it does.
#
# If it is at rest (in relation to us), it continues to be at rest. If it is moving East at 20 m/s, it continues moving East at 20 m/s. etc.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# This oil tanker has a large inertia. It is:
#
# hard to speed up
# hard to slow down when it is moving (can take many kilometres to stop)
# hard to change direction

# %% [raw]
# Newtons
# In honor of Sir Isaac Newton the unit of force is the Newton (abbreviation is N).
#
# A Newton is the force it takes to make 1 kg change its velocity by 1 m/s every second.
#
# In other words:	1 kg changes its velocity by 1 m/s every second
# Or:	1 kg changes 1 m/s per second
# Or:	1 kg  m/s  /s
# The two lots of "/s" (per second) become "/s2" (per second squared), so:
#
# 1 Newton is 1 kg m/s2 (kilogram metre per second squared)

# %% [raw]
# Forces are Interactions
#
# In the words of Sir Isaac Newton (his Third Law of Motion):
#
# "To every action there is always opposed an equal reaction"
#
# Today we say "Every action has an equal and opposite reaction"
#
# He also gave this example:
#
# "If you press a stone with your finger, the finger is also pressed by the stone."

# %% [raw]
# Relative
# Note: when we say something is "at rest" or "moving at 4 m/s" we forget to say "in relation to me" or "in relation to the ground", etc.
#
# earth rotate
# Think about this: are you really standing still? You are on planet Earth which is spinning at 40,075 km per day (about 1675 km/h or 465 m/s), and moving around the Sun at about 100,000 km/h, which is itself moving through the Galaxy.
#
# It is all relative!

# %% [raw]
# Newton's Three Laws
# Back in 1687 Newton wrote three laws about motion, which basically are:
#
# First Law: Inertia (force is needed to change an object's velocity)
# Second Law: F = ma
# Third Law: Every action has an equal and opposite reaction

# %% [markdown]
# # Subtracting

# %%
We can also subtract one vector from another:

first we reverse the direction of the vector we want to subtract,
then add them as usual:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Notation

# %%
A vector is often written in bold, like a or b.

A vector can also be written as the letters
of its head and tail with an arrow above it, like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Calculations

# %%
Now ... how do we do the calculations?

The most common way is to first break up vectors into x and y parts, like this:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# The vector a is broken up into the two vectors ax and ay

# %% [markdown]
# # Adding Vectors

# %% [raw]
# We can then add vectors by adding the x parts and adding the y parts:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# The vector (8, 13) and the vector (26, 7) add up to the vector (34, 20)

# %% [markdown]
# # Subtracting Vectors

# %% [raw]
# To subtract, first reverse the vector we want to subtract, then add.
#
# Example: subtract k = (4, 5) from v = (12, 2)
# a = v + −k
#
# a = (12, 2) + −(4, 5) = (12, 2) + (−4, −5) = (12−4, 2−5) = (8, −3)

# %% [markdown]
# # Magnitude of a Vector

# %% [raw]
# The magnitude of a vector is shown by two vertical bars on either side of the vector:
#
# |a|
#
# OR it can be written with double vertical bars (so as not to confuse it with absolute value):
#
# ||a||

# %% [raw]
# We use Pythagoras' theorem to calculate it:
#
# |a| = √( x2 + y2 )

# %% [raw]
# When a triangle has a right angle (90°) and squares are made on each of the three sides, then the biggest square has the exact same area as the other two squares put together!

# %% [raw]
# It is called "Pythagoras' Theorem" and can be written in one short equation:
#     a2 + b2 = c2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [raw]
# Note:
#
# c is the longest side of the triangle
# a and b are the other two sides
